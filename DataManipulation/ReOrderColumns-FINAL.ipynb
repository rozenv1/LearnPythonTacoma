# %%
import pandas as pd

# %%
df = pd.read_csv ('data/thomas_memorial_hospital_3501_20200529.csv')

# %%
df['Gender']=""

# %%
df['Race']=""

# %%
df['Ethnicity']=""

# %%
df['Code Status']=""

# %%
df.head()
# Out:
#           mrn patient_acct_no      patient_name  patient_zip_code  \
# 0  J000211436   64-J000211436   Justice, Howard           25309.0
# 1  J000224953   64-J000224953  Keeling, Orville           25567.0
# 2  J000700032   64-J000700032    Jones, Jessica           25702.0
# 3  J000189802   64-J000189802      Fields, Gary           25312.0
# 4  J000266711   64-J000266711      Moore, James           25177.0
#
#   date_of_birth admission_dt discharge_dt service_line  \
# 0     6/20/1975    3/20/2020    3/20/2020           HM
# 1      8/8/1944    3/20/2020     4/6/2020           HM
# 2      2/7/1981    3/20/2020    3/27/2020           HM
# 3     6/11/1975    3/20/2020    3/25/2020           HM
# 4     5/17/1957    3/20/2020    3/21/2020           HM
#
#   sound_discharging_clinician  surprise_question     ...     discharge_dx_cd  \
# 0        Ananthan Krishnathas                NaN     ...             G40.909
# 1      Rufina Nwanneka Odigwe                NaN     ...               E11.9
# 2           Usreesha Gourneni                NaN     ...               N17.9
# 3           Usreesha Gourneni                NaN     ...              M70.40
# 4        Ananthan Krishnathas                NaN     ...               E87.1
#
#    admit_dx      dx1     dx2     dx3     dx4 Gender Race Ethnicity Code Status
# 0   G40.909  G40.909  J01.20  E83.39  L89.91
# 1     J98.8    J98.8   C32.9  I48.91   N17.9
# 2     A41.9    A41.9   M00.9  E83.42     NaN
# 3     A41.9   M70.40   A41.9   Z72.0     NaN
# 4     E87.1    E87.1  R41.82   F31.9  I50.32
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (809, 25)

# %%
cols=list(df.columns.values)

# %%
cols
# Out:
# ['mrn',
#  'patient_acct_no',
#  'patient_name',
#  'patient_zip_code',
#  'date_of_birth',
#  'admission_dt',
#  'discharge_dt',
#  'service_line',
#  'sound_discharging_clinician',
#  'surprise_question',
#  'covid_status',
#  'stay_id',
#  'sc_site_id',
#  'hospital_name',
#  'discharge_group_desc',
#  'discharge_dx_cd',
#  'admit_dx',
#  'dx1',
#  'dx2',
#  'dx3',
#  'dx4',
#  'Gender',
#  'Race',
#  'Ethnicity',
#  'Code Status']

# %%
df1=df[['mrn', 'patient_acct_no', 'patient_name', 'date_of_birth', 'admission_dt', 'discharge_dt', 'admit_dx','service_line', 'sound_discharging_clinician', 'surprise_question','patient_zip_code', 'Gender', 'Race', 'Ethnicity', 'discharge_group_desc', 'Code Status', 'covid_status']]

# %%
df1.head()
# Out:
#           mrn patient_acct_no      patient_name date_of_birth admission_dt  \
# 0  J000211436   64-J000211436   Justice, Howard     6/20/1975    3/20/2020
# 1  J000224953   64-J000224953  Keeling, Orville      8/8/1944    3/20/2020
# 2  J000700032   64-J000700032    Jones, Jessica      2/7/1981    3/20/2020
# 3  J000189802   64-J000189802      Fields, Gary     6/11/1975    3/20/2020
# 4  J000266711   64-J000266711      Moore, James     5/17/1957    3/20/2020
#
#   discharge_dt admit_dx service_line sound_discharging_clinician  \
# 0    3/20/2020  G40.909           HM        Ananthan Krishnathas
# 1     4/6/2020    J98.8           HM      Rufina Nwanneka Odigwe
# 2    3/27/2020    A41.9           HM           Usreesha Gourneni
# 3    3/25/2020    A41.9           HM           Usreesha Gourneni
# 4    3/21/2020    E87.1           HM        Ananthan Krishnathas
#
#    surprise_question  patient_zip_code Gender Race Ethnicity  \
# 0                NaN           25309.0
# 1                NaN           25567.0
# 2                NaN           25702.0
# 3                NaN           25312.0
# 4                NaN           25177.0
#
#        discharge_group_desc Code Status  covid_status
# 0                   Unknown              Not screened
# 1                       SNF              No suspicion
# 2  Home - Private Residence              No suspicion
# 3  Home - Private Residence              No suspicion
# 4  Home - Private Residence              Not screened

# %%
df1.to_csv('3501_Thomas_Memorial_Hospital_20200529.csv')
