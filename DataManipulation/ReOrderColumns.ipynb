# %%
import pandas as pd

# %%
df = pd.read_csv ('data/texas_health_hughley_fort_worth_south_2847_20200529.csv')

# %%
df.head()
# Out:
#        mrn patient_acct_no       patient_name  patient_zip_code date_of_birth  \
# 0  6304549    75-006304549  GARCIA, ALEJANDRO             76059     4/28/1966
# 1   229048    75-000229048     CLIFTON, TOMMY             76031     3/17/1943
# 2  6353013    75-006353013    WILLIAMS, GORIE             76140     5/26/1935
# 3   306843    75-000306843  WILBANKS, SHIRLEY             76031     3/15/1937
# 4  6345249    75-006345249        GREEN, CORA             76008     10/8/1942
#
#   admission_dt discharge_dt service_line sound_discharging_clinician  \
# 0    3/20/2020    3/28/2020           HM        Abdulatif Adnan Jabi
# 1    3/20/2020    3/20/2020           HM   Raghavendri Chigullapally
# 2    3/20/2020    3/26/2020           HM        Abdulatif Adnan Jabi
# 3    3/20/2020    3/23/2020           HM          Sirisha Bheemaneni
# 4    3/20/2020    3/31/2020           HM               Ashok Valluri
#
#   surprise_question   ...    stay_id  sc_site_id  \
# ...

# %%
df.shape
# Out:
# (1365, 21)

# %%
cols=list(df.columns.values)

# %%
cols
# Out:
# ['mrn',
#  'patient_acct_no',
#  'patient_name',
#  'patient_zip_code',
#  'date_of_birth',
#  'admission_dt',
#  'discharge_dt',
#  'service_line',
#  'sound_discharging_clinician',
#  'surprise_question',
#  'covid_status',
#  'stay_id',
#  'sc_site_id',
#  'hospital_name',
#  'discharge_group_desc',
#  'discharge_dx_cd',
#  'admit_dx',
#  'dx1',
#  'dx2',
#  'dx3',
#  'dx4']

# %%
df1=df[['mrn', 'patient_acct_no', 'patient_name', 'date_of_birth', 'admission_dt', 'discharge_dt', 'admit_dx','service_line', 'sound_discharging_clinician', 'surprise_question','patient_zip_code', 'discharge_group_desc', 'covid_status']]

# %%
df1.head()
# Out:
#        mrn patient_acct_no       patient_name date_of_birth admission_dt  \
# 0  6304549    75-006304549  GARCIA, ALEJANDRO     4/28/1966    3/20/2020
# 1   229048    75-000229048     CLIFTON, TOMMY     3/17/1943    3/20/2020
# 2  6353013    75-006353013    WILLIAMS, GORIE     5/26/1935    3/20/2020
# 3   306843    75-000306843  WILBANKS, SHIRLEY     3/15/1937    3/20/2020
# 4  6345249    75-006345249        GREEN, CORA     10/8/1942    3/20/2020
#
#   discharge_dt admit_dx service_line sound_discharging_clinician  \
# 0    3/28/2020    A41.9           HM        Abdulatif Adnan Jabi
# 1    3/20/2020    G45.9           HM   Raghavendri Chigullapally
# 2    3/26/2020    K92.2           HM        Abdulatif Adnan Jabi
# 3    3/23/2020   K72.00           HM          Sirisha Bheemaneni
# 4    3/31/2020    J86.0           HM               Ashok Valluri
#
#   surprise_question  patient_zip_code      discharge_group_desc  covid_status
# ...

# %%
df1.to_csv('ReOrdered.csv')
